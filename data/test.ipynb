# %%
import numpy as np
import pandas as pd

# %%
enterobacteriaceae_bacteria = [
    'Normal E.coli',
    'EHEC or EIEC',
    'Shigella',
    'Klebsiella pneumoniae',
    'Klebsiella oxytoca',
    'Enterobacter',
    'Serratia',
    'Proteus mirabilis',
    'Proteus vulgaris',
    'Providencia',
    'Morganella',
    'Salmonella typhi',
    'Salmonella paratyphi A',
    'Salmonella paratyphi other groups',
    'Salmonella arizona',
    'Edwardsiella',
    'Citrobacter freundii',
    'Citrobacter diversus'
]

# %%
nfb_bacteria = [
    'Pseudomonas aeruginosa',
    'Alcaligenes faecalis',
    'Burkholderia cepacia',
    'Cryseobacterium meningosepticum',
    'Moraxella catarrhalis',
    'Moraxella lacunata',
    'Shewanella putrefaciens',
    'Acinetobacter baumannii',
    'Acinetobacter lwoffii',
    'Stenotrophomonas maltophilia',
]

# %%
gram_positive_bacteria = [
    'Micrococcus',
    'Staphylococcus areus',
    'Staphylococcus epidermidis',
    'Staphylococcus saprophyticus',
    'Streptococcus pyogenes (group A)',
    'Streptococcus agalactiae (group B)',
    'Streptococcus pneumoniae',
    'Streptococcus viridians',
    'Enterococcus',
    'Non-Enterococcus'
]

# %%
enterobacteriaceae_bacteria_tests = pd.DataFrame({
    'Oxidase': ['-', '-', '-', '-', '-',
                '-', '-', '-', '-', '-',
                '-', '-', '-', '-', '-',
                '-', '-', '-'],
    'TSI': ['A/A', 'K/A', 'K/A', 'A/A', 'A/A',
            'A/A', 'A/A', 'K/A', 'A/A', 'K/A',
            'K/A', 'K/A', 'K/A', 'K/A', 'K/A',
            'K/A', 'A/A or K/A', 'A/A'],
    'OF': 'F+',
    'Urease': ['-', '-', '-', '+', '-',
               '-', '-', '+', '+', '+',
               '+', '-', '-', '-', '-',
               '-', '-', '-'],
    'PD': ['-', '-', '-', '-', '-',
               '-', '-', '+', '+', '+',
               '+', '-', '-', '-', '-',
               '-', '-', '-'],
    'IMViC': ['++--',
              '++--',
              '-+--',
              '--++',
              '+-++',
              '--++',
              '--++',
              '-+vv',
              '++vv',
              '++vv',
              '++vv',
              '-+vv',
              '-+vv',
              '-+vv',
              '-+vv',
              '++-+',
              '-+-+',
              '++++'],
    'Motility': ['+', '+', '-', '-', '-',
                 '+', '+', '+', '+', '+',
                 '+', '+', '+', '+', '+',
                 '+', '+', '+'],
    'H2S': ['-', '-', '-', '-', '-',
            '-', '-', '+', '+', '+',
            '-', '+', '-', '+', '+',
            '+', '+', '-'],
    'LDC': ['+', '+', '-', 'NI', 'NI',
            'NI', 'NI', 'NI', 'NI', 'NI',
            'NI', '+', '+', '+', '+',
            '+', '-', '-'],
    'ONPG': ['NI', '+', '-', 'NI', 'NI',
             'NI', '-', 'NI', 'NI', 'NI',
             'NI', 'NI', 'NI', 'NI', 'NI',
             'NI', '+', '+']
}, index=enterobacteriaceae_bacteria)

# %%
enterobacteriaceae_bacteria_tests
# Out:
#                                   Oxidase         TSI  OF Urease PD IMViC  \
# Normal E.coli                           -         A/A  F+      -  -  ++--
# EHEC or EIEC                            -         K/A  F+      -  -  ++--
# Shigella                                -         K/A  F+      -  -  -+--
# Klebsiella pneumoniae                   -         A/A  F+      +  -  --++
# Klebsiella oxytoca                      -         A/A  F+      -  -  +-++
# Enterobacter                            -         A/A  F+      -  -  --++
# Serratia                                -         A/A  F+      -  -  --++
# Proteus mirabilis                       -         K/A  F+      +  +  -+vv
# Proteus vulgaris                        -         A/A  F+      +  +  ++vv
# Providencia                             -         K/A  F+      +  +  ++vv
# Morganella                              -         K/A  F+      +  +  ++vv
# Salmonella typhi                        -         K/A  F+      -  -  -+vv
# ...

# %%
enterobacteriaceae_bacteria_tests.style.set_properties(
    subset=['Oxidase', 'Urease', 'PD', 'IMViC',
            'Motility', 'H2S', 'LDC', 'ONPG'],
    **{'text-align': 'center'}
)
# Out:
# <style type="text/css">
# ...

# %%
nfb_bacteria
# Out:
# ['Pseudomonas aeruginosa',
#  'Alcaligenes faecalis',
#  'Burkholderia cepacia',
#  'Cryseobacterium meningosepticum',
#  'Moraxella catarrhalis',
#  'Moraxella lacunata',
#  'Shewanella putrefaciens',
#  'Acinetobacter baumannii',
#  'Acinetobacter lwoffii',
#  'Stenotrophomonas maltophilia']

# %%
nfb_bacteria_tests = pd.DataFrame({
    'Oxidase': ['+', '+', '+', '+', '+',
                '+', '+', '-', '-', '-'],
    'TSI': 'K/K',
    'OF': ['O+', 'NR', 'O+', 'O+', 'NR',
           'NR', 'O+', 'O+', 'NR', 'NR'],
    'Urease': '-',
    'PD': '-',
    'IMViC': ['-+v+',
              '-+v+',
              '-+v+',
              '++v-',
              '-+v-',
              '-+v-',
              '-+v-',
              '-+vv',
              '-+vv',
              '-+v+'],
    'Motility': ['+', '+', '+', '-', '-',
                '-', '+', '-', '-', '-'],
    'H2S': ['-', '-', '-', '-', '-',
            '-', '+', '-', '-', '-'],
    'LDC': 'NI',
    'ONPG': 'NI'
}, index=nfb_bacteria)

nfb_bacteria_tests
# Out:
#                                 Oxidase  TSI  OF Urease PD IMViC Motility H2S  \
# Pseudomonas aeruginosa                +  K/K  O+      -  -  -+v+        +   -
# Alcaligenes faecalis                  +  K/K  NR      -  -  -+v+        +   -
# Burkholderia cepacia                  +  K/K  O+      -  -  -+v+        +   -
# Cryseobacterium meningosepticum       +  K/K  O+      -  -  ++v-        -   -
# Moraxella catarrhalis                 +  K/K  NR      -  -  -+v-        -   -
# Moraxella lacunata                    +  K/K  NR      -  -  -+v-        -   -
# Shewanella putrefaciens               +  K/K  O+      -  -  -+v-        +   +
# Acinetobacter baumannii               -  K/K  O+      -  -  -+vv        -   -
# Acinetobacter lwoffii                 -  K/K  NR      -  -  -+vv        -   -
# Stenotrophomonas maltophilia          -  K/K  NR      -  -  -+v+        -   -
#
#                                 LDC ONPG
# Pseudomonas aeruginosa           NI   NI
# ...

# %%
nfb_bacteria_tests.loc['Burkholderia cepacia', 'LDC'] = '+'
nfb_bacteria_tests.loc['Stenotrophomonas maltophilia', 'LDC'] = '+'
nfb_bacteria_tests
# Out:
#                                 Oxidase  TSI  OF Urease PD IMViC Motility H2S  \
# Pseudomonas aeruginosa                +  K/K  O+      -  -  -+v+        +   -
# Alcaligenes faecalis                  +  K/K  NR      -  -  -+v+        +   -
# Burkholderia cepacia                  +  K/K  O+      -  -  -+v+        +   -
# Cryseobacterium meningosepticum       +  K/K  O+      -  -  ++v-        -   -
# Moraxella catarrhalis                 +  K/K  NR      -  -  -+v-        -   -
# Moraxella lacunata                    +  K/K  NR      -  -  -+v-        -   -
# Shewanella putrefaciens               +  K/K  O+      -  -  -+v-        +   +
# Acinetobacter baumannii               -  K/K  O+      -  -  -+vv        -   -
# Acinetobacter lwoffii                 -  K/K  NR      -  -  -+vv        -   -
# Stenotrophomonas maltophilia          -  K/K  NR      -  -  -+v+        -   -
#
#                                 LDC ONPG
# Pseudomonas aeruginosa           NI   NI
# ...

# %%
enterobacteriaceae_bacteria_tests
# Out:
#                                   Oxidase         TSI  OF Urease PD IMViC  \
# Normal E.coli                           -         A/A  F+      -  -  ++--
# EHEC or EIEC                            -         K/A  F+      -  -  ++--
# Shigella                                -         K/A  F+      -  -  -+--
# Klebsiella pneumoniae                   -         A/A  F+      +  -  --++
# Klebsiella oxytoca                      -         A/A  F+      -  -  +-++
# Enterobacter                            -         A/A  F+      -  -  --++
# Serratia                                -         A/A  F+      -  -  --++
# Proteus mirabilis                       -         K/A  F+      +  +  -+vv
# Proteus vulgaris                        -         A/A  F+      +  +  ++vv
# Providencia                             -         K/A  F+      +  +  ++vv
# Morganella                              -         K/A  F+      +  +  ++vv
# Salmonella typhi                        -         K/A  F+      -  -  -+vv
# ...

# %%
nfb_bacteria_tests
# Out:
#                                 Oxidase  TSI  OF Urease PD IMViC Motility H2S  \
# Pseudomonas aeruginosa                +  K/K  O+      -  -  -+v+        +   -
# Alcaligenes faecalis                  +  K/K  NR      -  -  -+v+        +   -
# Burkholderia cepacia                  +  K/K  O+      -  -  -+v+        +   -
# Cryseobacterium meningosepticum       +  K/K  O+      -  -  ++v-        -   -
# Moraxella catarrhalis                 +  K/K  NR      -  -  -+v-        -   -
# Moraxella lacunata                    +  K/K  NR      -  -  -+v-        -   -
# Shewanella putrefaciens               +  K/K  O+      -  -  -+v-        +   +
# Acinetobacter baumannii               -  K/K  O+      -  -  -+vv        -   -
# Acinetobacter lwoffii                 -  K/K  NR      -  -  -+vv        -   -
# Stenotrophomonas maltophilia          -  K/K  NR      -  -  -+v+        -   -
#
#                                 LDC ONPG
# Pseudomonas aeruginosa           NI   NI
# ...

# %%
gram_negative_bacteria_chart = pd.concat([enterobacteriaceae_bacteria_tests, nfb_bacteria_tests])
gram_negative_bacteria_chart
# Out:
#                                   Oxidase         TSI  OF Urease PD IMViC  \
# Normal E.coli                           -         A/A  F+      -  -  ++--
# EHEC or EIEC                            -         K/A  F+      -  -  ++--
# Shigella                                -         K/A  F+      -  -  -+--
# Klebsiella pneumoniae                   -         A/A  F+      +  -  --++
# Klebsiella oxytoca                      -         A/A  F+      -  -  +-++
# Enterobacter                            -         A/A  F+      -  -  --++
# Serratia                                -         A/A  F+      -  -  --++
# Proteus mirabilis                       -         K/A  F+      +  +  -+vv
# Proteus vulgaris                        -         A/A  F+      +  +  ++vv
# Providencia                             -         K/A  F+      +  +  ++vv
# Morganella                              -         K/A  F+      +  +  ++vv
# Salmonella typhi                        -         K/A  F+      -  -  -+vv
# ...

# %%
enterobacteriaceae_bacteria_tests.index.name = 'Bacteria'
nfb_bacteria_tests.index.name = 'Bacteria'
gram_negative_bacteria_chart.index.name = 'Bacteria'

# %%
enterobacteriaceae_bacteria_tests
# Out:
#                                   Oxidase         TSI  OF Urease PD IMViC  \
# Bacteria
# Normal E.coli                           -         A/A  F+      -  -  ++--
# EHEC or EIEC                            -         K/A  F+      -  -  ++--
# Shigella                                -         K/A  F+      -  -  -+--
# Klebsiella pneumoniae                   -         A/A  F+      +  -  --++
# Klebsiella oxytoca                      -         A/A  F+      -  -  +-++
# Enterobacter                            -         A/A  F+      -  -  --++
# Serratia                                -         A/A  F+      -  -  --++
# Proteus mirabilis                       -         K/A  F+      +  +  -+vv
# Proteus vulgaris                        -         A/A  F+      +  +  ++vv
# Providencia                             -         K/A  F+      +  +  ++vv
# Morganella                              -         K/A  F+      +  +  ++vv
# ...

# %%
nfb_bacteria_tests
# Out:
#                                 Oxidase  TSI  OF Urease PD IMViC Motility H2S  \
# Bacteria
# Pseudomonas aeruginosa                +  K/K  O+      -  -  -+v+        +   -
# Alcaligenes faecalis                  +  K/K  NR      -  -  -+v+        +   -
# Burkholderia cepacia                  +  K/K  O+      -  -  -+v+        +   -
# Cryseobacterium meningosepticum       +  K/K  O+      -  -  ++v-        -   -
# Moraxella catarrhalis                 +  K/K  NR      -  -  -+v-        -   -
# Moraxella lacunata                    +  K/K  NR      -  -  -+v-        -   -
# Shewanella putrefaciens               +  K/K  O+      -  -  -+v-        +   +
# Acinetobacter baumannii               -  K/K  O+      -  -  -+vv        -   -
# Acinetobacter lwoffii                 -  K/K  NR      -  -  -+vv        -   -
# Stenotrophomonas maltophilia          -  K/K  NR      -  -  -+v+        -   -
#
#                                 LDC ONPG
# Bacteria
# Pseudomonas aeruginosa           NI   NI
# ...

# %%
gram_negative_bacteria_chart
# Out:
#                                   Oxidase         TSI  OF Urease PD IMViC  \
# Bacteria
# Normal E.coli                           -         A/A  F+      -  -  ++--
# EHEC or EIEC                            -         K/A  F+      -  -  ++--
# Shigella                                -         K/A  F+      -  -  -+--
# Klebsiella pneumoniae                   -         A/A  F+      +  -  --++
# Klebsiella oxytoca                      -         A/A  F+      -  -  +-++
# Enterobacter                            -         A/A  F+      -  -  --++
# Serratia                                -         A/A  F+      -  -  --++
# Proteus mirabilis                       -         K/A  F+      +  +  -+vv
# Proteus vulgaris                        -         A/A  F+      +  +  ++vv
# Providencia                             -         K/A  F+      +  +  ++vv
# Morganella                              -         K/A  F+      +  +  ++vv
# ...
